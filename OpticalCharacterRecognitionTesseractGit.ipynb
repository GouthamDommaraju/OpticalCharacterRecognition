# %% [markdown]
# **Optical Character Recognition (OCR) using google's Tesseract OCR**

# %%
# Install pytessaract
# !sudo apt install tesseract-ocr
# !pip install pytesseract

# %%
# Python-tesseract is a wrapper for Google’s Tesseract-OCR Engine 
import pytesseract

# %%
# read image using matplotlib 
  
# importing matplotlib modules 
import matplotlib.image as mpimg 
import matplotlib.pyplot as plt 
  
# Read Images 
img = mpimg.imread('Input.png') 
  
# Output Images 
plt.imshow(img)

# %%
# Image to String Conversion
print(pytesseract.image_to_string('Input.png'))
# Out:
# “HHH HEHEHE
# #888 Cross Tab Analysis ###i##
# sHEHEEEEEHeEtEEEE EERE ES
# CrossTab=read.csv("CrossTab_Example.csv", ,header
#
#
#
# RUE) 5
#
# dim(CrossTab) # check that the data has the expected number of rows and columns
# head(CrossTab) # check the first few rows
#
# summary(CrossTab) # brief descriptive summary about the data.
#
# ## simple frequency analysis
# AccountSize<-table(CrossTab[,2]) #Account Size
#
# # if you want to add column names
# dimnames(AccountSize)<- list(c("Small", "Medium", “Large”))
#
# Recommendation<-table(CrossTab[ ,3]) #Recommendation
# chisg.test(Reconmendation) ## are proportions equal?
#
# n=dim(CrossTab)[1] #total sample size
# table(CrossTab[,2])/n #percentage table
#
# ## simple CrossTab Frequency without package
# mytable=t(table(CrossTab[ ,2],CrossTab[,3])) #CrossTab Frequency
#
# statistical testing
# chisq.test(mytable)
#
# ### Lets use package for CrossTab analysis ###
# library(gmodels) #Let's use Package
#
# CrossTable(CrossTab[,3],CrossTab[,2],
# dnn=c("Recomm” ,"AcctSize"))
